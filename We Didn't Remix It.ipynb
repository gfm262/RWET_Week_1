# %% [markdown]
# # We Didn't Start the Remix
#
# For this project, I took the lyrics from Billy Joel's "We Didn't Start the Fire" and remixed them using the [Dadaist Poem Code Example](https://render.githubusercontent.com/view/ipynb?commit=119d55f57f4cae3eba15824655bb655564bc1a2a&enc_url=68747470733a2f2f7261772e67697468756275736572636f6e74656e742e636f6d2f61706172726973682f727765742f313139643535663537663463616533656261313538323436353562623635353536346263316132612f736f6d652d706f657472792d67656e657261746f72732e6970796e62&nwo=aparrish%2Frwet&path=some-poetry-generators.ipynb&repository_id=119094188&repository_type=Repository#To-Make-a-Dadaist-Poem) provided in the homework examples.
#
# I chose the song as the source for this project as I as [working with it for another class where we were making cut-up poetry for an assignment](https://www.martinsquared.com/2020/09/12/the-we-didnt-start-it-story-teller/) and I felt that it lent itself really well to remixing.
#
# I changed this up from the example given by including parameters to limited the maximum number of lines (max_lines=15) and changing the "..." at the end of the truncated verses with an exclamation mark (placeholder="!"). I also added choruses between the verses and finished it off with the iconic ending line of the song.
#
# I really enjoyed running this notebook a number of times. In addition to such gems as "JFK, Sally Little Fortune", Chubby Ole Ho crack" and lines like this that seemed to group locations (though the order is random): "Budapest, China, Pacific, shores, Around Elvis".
#
# In terms of coding, I'm starting to feel like all the hours and hours of coding practice and reading MDN Docs and searching through stackoverflow are starting to pay off. I was able to figure out how to get this notebook working how I envisioned it relatively easily. Ideally, I would have been able to remove any commas at the ends of verses (so you wouldn't have a ",!"), but I figure that's something we'll learn to do this semester. You're welcome to copy this code to a notebook and try it yourself... the results just go on and on and on and on. (Sorry, I couldn't resist!)

# %%
import random
import textwrap

fire_words = """
Harry Truman, Doris Day, Red China, Johnnie Ray, South Pacific, Walter Winchell,
Joe DiMaggio, Joe McCarthy, Richard Nixon, Studebaker, television, North Korea,
South Korea, Marilyn Monroe, Rosenbergs, H-bomb, Sugar Ray, Panmunjom, Brando,
"The King and I" and "The Catcher in the Rye", Eisenhower, vaccine, England's got a new queen,
Marciano, Liberace, Santayana goodbye! 
Joseph Stalin, Malenkov, Nasser and Prokofiev, Rockefeller, Campanella, Communist Bloc,
Roy Cohn, Juan Peron, Toscanini, Dacron, Dien Bien Phu falls, "Rock Around the Clock",
Einstein, James Dean, Brooklyn's got a winning team, Davy Crockett, Peter Pan, Elvis Presley,
Disneyland, Bardot, Budapest, Alabama, Krushchev, Princess Grace, "Peyton Place",
trouble in the Suez! 
Little Rock, Pasternak, Mickey Mantle, Kerouac, Sputnik, Chou En-Lai, "Bridge on the River Kwai",
Lebanon, Charlse de Gaulle, California baseball, Starkweather, homicide, children of thalidomide,
Buddy Holly, "Ben Hur", space monkey, Mafia, Hula hoops, Castro, Edsel is a no-go, U2, Syngman Rhee,
payola and Kennedy, Chubby Checker, "Psycho", Belgians in the Congo! 
Hemingway, Eichmann, "Stranger in a Strange Land", Dylan, Berlin, Bay of Pigs invasion, 
"Lawrence of Arabia", British Beatlemania, Ole Miss, John Glenn, Liston beats Patterson, Pope Paul,
Malcolm X, British politician sex, JFK, blown away, what else do I have to say! 
Birth control, Ho Chi Minh, Richard Nixon back again, Moonshot, Woodstock, Watergate, punk rock,
Begin, Reagan, Palestine, terror on the airline, Ayatollah's in Iran, Russians in Afghanistan, 
"Wheel of Fortune", Sally Ride, heavy metal, suicide, Foreign debts, homeless vets, AIDS, crack,
Bernie Goetz, Hypodermics on the shores, China's under martial law, Rock and roller cola wars, I can't take it any more"""

not_us="""
We didn't start the fire.
It was always burning
Since the world's been turning!
We didn't start the fire.
No we didn't light it,
But we tried to fight it!
"""
on_and_on_and_on_and_on ="""
Will it still burn on, and on, and on, and on?
"""

lyrics = fire_words.split()
random.shuffle(lyrics)

print(textwrap.fill(" ".join(lyrics), 50, max_lines=15, placeholder="!"))
print(not_us)
random.shuffle(lyrics)
print(textwrap.fill(" ".join(lyrics), 50, max_lines=15, placeholder="!"))
print(not_us)
random.shuffle(lyrics)
print(textwrap.fill(" ".join(lyrics), 50, max_lines=15, placeholder="!"))
print(not_us + on_and_on_and_on_and_on)
# Out:
# River X, North Peron, "Psycho", Brando, Panmunjom,
# Charlse what invasion, Berlin, Ride, Kerouac,
# Rhee, Bien children Belgians Holly, Davy Grace,
# the vets, Red Russians in Korea, Edsel Harry
# Prokofiev, and Bloc, Bernie a I thalidomide, blown
# and wars, else I" and Hypodermics Little
# Toscanini, Juan Around the the say! Mantle,
# "Lawrence Pope Sputnik, have a Watergate, goodbye!
# Doris airline, on China's Mickey McCarthy, Marilyn
# Bardot, to Pan, Patterson, the Glenn, Ray, Nixon
# Goetz, Woodstock, Gaulle, no-go, Krushchev, can't
# Crockett, Malenkov, "The falls, Foreign Cohn, in
# queen, a Liston Ray, Rock, Reagan, U2, Princess
# hoops, Joe control, Mafia, Sally Pigs more British
# rock, Fortune", "Peyton Johnnie trouble!
#
# We didn't start the fire.
# It was always burning
# Since the world's been turning!
# We didn't start the fire.
# No we didn't light it,
# But we tried to fight it!
#
# on Russians queen, Fortune", Gaulle, away, Stalin,
# ...
